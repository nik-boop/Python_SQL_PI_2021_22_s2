# %% [markdown]
# <img src="../Img/Python_SQL_PI.png" style="width:100%">
#
#
# <p style="font-size:22px;text-align:center">Семинар 3.1. Преобразование вывода и функции</p>
#
# <a id = Home></a>
#
# 7 марта 2022 года, пн<br>
# Поток: ПИ20-1, ПИ20-2, ПИ20-3, ПИ20-4, ПИ20-5, ПИ20-6 (4 подгруппа)<br>
# ПИ20-1, ПИ20-2, ПИ20-3, ПИ20-4, ПИ20-5, ПИ20-6 (3 подгруппа)
#
# 10 марта 2022 года, чт<br>
# ПИ20-1, ПИ20-2, ПИ20-3, ПИ20-4, ПИ20-5, ПИ20-6 (1 подгруппа)<br>
# ПИ20-1, ПИ20-2, ПИ20-3, ПИ20-4, ПИ20-5, ПИ20-6 (2 подгруппа)

# %% [markdown]
# ```
# STUDENT
# STUDENT_ID — числовой код, идентифицирующий студента (идентификатор студента),
# SURNAME — фамилия студента,
# NAME — имя студента,
# STIPEND — стипендия, которую получает студент,
# KURS — курс, на котором учится студент,
# CITY — город, в котором живет студент,
# BIRTHDAY — дата рождения студента,
# UNIV_ID — идентификатор университета, в котором учится студент.
#
#
# LECTURER
# LECTURER_ID — идентификатор преподавателя,
# SURNAME — фамилия преподавателя,
# NAME — имя преподавателя,
# CITY — город, в котором живет преподаватель,
# UNIV_ID — идентификатор университета, в котором работает преподаватель
#
#
# SUBJECT
# SUBJ_ID — идентификатор предмета обучения,
# SUBJ_NAME — наименование предмета обучения,
# HOUR — количество часов, отводимых на изучение предмета,
# SEMESTER — семестр, в котором изучается данный предмет.
#
#
# UNIVERSITY
# UNIV_ID — идентификатор университета,
# UNIV_NAME — название университета,
# RATING — рейтинг университета,
# CITY — город, в котором расположен университет.
#
#
# EXAM_MARKS
# EXAM_ID — идентификатор экзамена,
# STUDENT_ID — идентификатор студента,
# SUBJ_ID — идентификатор предмета обучения,
# MARK — экзаменационная оценка,
# EXAM_DATE — дата экзамена.
#
#
# SUBJ_LECT
# LECTURER_ID — идентификатор преподавателя,
# SUBJ_ID — идентификатор предмета обучения.
# ```
#
# <img src="../Img/Students_Schema.png" style="width:60%">
#
#
#
# <img src=../Img/pencil.png style="width:190px;height:190px">
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните задания c помощью Jupyter Notebook и языка програмирования Python</p>
#
# 1. Составьте запрос для таблицы STUDENT таким образом, чтобы в результат содержал только студентов, чья фамилия заканчивается на "ова" и чтобы выходная таблица содержала всего один столбец в следующем виде: В. Кудряшова; место жительства - Нижневартовск; день рождения 2002-02-18.
# 2. Составьте запрос, выводящий фамилии, имена студентов и величину получаемых ими стипендий, при этом значения стипендий должны быть увеличены в 100 раз.
# 3. Составьте запрос для таблицы UNIVERSITY таким образом, чтобы выходная таблица содержала всего один столбец в следующем виде: Код-10; ВГУ-г.ВОРОНЕЖ; Рейтинг=296.

# %% [markdown]
# # Решение

# %%
# Ваш код здесь

import sqlite3

# %%
conn = sqlite3.connect("../Data/Students.db")
crs = conn.cursor()

# %%
# 1

"""
 В. Кудряшова; место жительства - Нижневартовск; день рождения 2002-02-18.
"""

s = """
SELECT substr(name, 1, 1) || '. ' || surname || '; место жительства - ' || city || '; день рождения ' || 
    date(birthday) as INFO
FROM student
WHERE surname LIKE '%ова'
"""

crs.execute(s).fetchall()
# Out:
# [('В. Кудряшова; место жительства - Нижневартовск; день рождения 2002-02-18',),
#  ('П. Рожкова; место жительства - Рубцовск; день рождения 2001-09-15',),
#  ('И. Соколова; место жительства - Колпашево; день рождения 2002-06-25',),
#  ('В. Семенова; место жительства - Вологда; день рождения 2003-10-04',),
#  ('В. Некрасова; место жительства - Иркутск; день рождения 2004-08-23',),
#  ('О. Казакова; место жительства - Кемерово; день рождения 2000-03-29',),
#  ('А. Миронова; место жительства - Владикавказ; день рождения 2000-10-08',),
#  ('Л. Одинцова; место жительства - Верхний Баскунчак; день рождения 2002-03-07',),
#  ('З. Игнатова; место жительства - Ростов; день рождения 2000-09-26',),
#  ('Д. Мельникова; место жительства - Архангельск; день рождения 2002-08-01',),
#  ('В. Фролова; место жительства - Кисловодск; день рождения 1999-06-02',),
#  ('М. Казакова; место жительства - Нальчик; день рождения 1994-02-18',),
#  ('Ф. Жукова; место жительства - Магадан; день рождения 1998-10-06',),
#  ('И. Жданова; место жительства - Тверь; день рождения 2002-03-02',),
#  ('С. Мельникова; место жительства - Кропоткин (Краснод.); день рождения 1998-03-24',),
#  ('А. Вишнякова; место жительства - Иваново; день рождения 2002-02-10',),
#  ('М. Борисова; место жительства - Рославль; день рождения 1995-08-07',),
#  ('А. Воронова; место жительства - Усть-Джегута; день рождения 1999-02-04',),
#  ('Е. Петрова; место жительства - Белгород; день рождения 2001-05-21',),
#  ('М. Иванова; место жительства - Липецк; день рождения 2002-04-11',),
#  ('Ф. Миронова; место жительства - Москва; день рождения 2002-04-15',)]

# %%
#2
s="""
SELECT surname, name, stipend*100 as stipend
FROM student
"""
crs.execute(s).fetchall()[:10]
# Out:
# [('Иванов', 'Иван', 15000),
#  ('Петров', 'Петр', 20000),
#  ('Сидоров', 'Вадим', 15000),
#  ('Кузнецов', 'Борис', 0),
#  ('Зайцева', 'Ольга', 25000),
#  ('Котов', 'Павел', 15000),
#  ('Белкин', 'Вадим', 25000),
#  ('Дуб', 'Елизавета', 15000),
#  ('Кудряшова', 'Вера', 10000),
#  ('Журавлева', 'Вера', 0)]

# %%
#3 Составьте запрос для таблицы UNIVERSITY таким образом, чтобы выходная таблица содержала всего один столбец 
#в следующем виде: Код-10; ВГУ-г.ВОРОНЕЖ; Рейтинг=296

s = '''
SELECT 'Код-' || univ_id || ';' || univ_name || '-г.' || city || ';' || 'Рейтинг=' || rating
FROM UNIVERSITY
'''
crs.execute(s).fetchall()
# Out:
# [('Код-10;ВГУ-г.Воронеж;Рейтинг=296',),
#  ('Код-11;НГУ-г.Новосибирск;Рейтинг=345',),
#  ('Код-12;МФТИ-г.Москва;Рейтинг=500',),
#  ('Код-14;БГУ-г.Белгород;Рейтинг=326',),
#  ('Код-15;ТГУ-г.Томск;Рейтинг=368',),
#  ('Код-18;ВГМА-г.Воронеж;Рейтинг=327',),
#  ('Код-22;МГУ-г.Москва;Рейтинг=606',),
#  ('Код-32;РГУ-г.Ростов;Рейтинг=416',),
#  ('Код-44;ФинУ-г.Москва;Рейтинг=330',),
#  ('Код-45;МГТУ им. Баумана-г.Москва;Рейтинг=372',),
#  ('Код-46;ФГБОУ "Политех"-г.Санкт-Петербург;Рейтинг=300',),
#  ('Код-47;КФУ-г.Казань;Рейтинг=330',),
#  ('Код-48;УЛГУ-г.Ульяновск;Рейтинг=231',)]

# %% [markdown]
# <img src=../Img/pencil.png style="width:190px;height:190px">
#
# <p style="background-color:powderblue; font-size:125%; color: rebeccapurple;">Выполните задания</p>
# <p>Выполните указанные задания c помощью Python в интерактивной среде Jupyter notebook</p>
#
# 1. Напишите запрос для подсчета количества студентов, сдававших экзамен по предмету обучения с идентификатором 73.
# 2. Напишите запрос, который позволяет подсчитать в таблице EXAM_MARKS количество различных предметов обучения.
# 3. Напишите запрос, который для каждого студента выполняет выборку его идентификатора и минимальной из полученных им оценок.
# 4. Напишите запрос, который для каждого студента выполняет выборку его идентификатора и максимальной из полученных им оценок.
# 5. Напишите запрос, выполняющий вывод первой по алфавиту фамилии студента, начинающейся на букву "И".
# 6. Напишите запрос, который для каждого предмета обучения выводит наименование предмета и максимальное значение номера семестра, в котором этот предмет преподается.
# 7. Напишите запрос, который для каждого конкретного дня сдачи экзамена выводит данные о количестве студентов, сдававших экзамен в этот день.
# 8. Напишите запрос, выдающий средний балл для каждого студента.
# 9. Напишите запрос, выдающий средний балл для экзамена по каждому предмету.
# 10. Напишите запрос, определяющий количество сдававших студентов для каждого предмета (оценка больше двух).
# 11. Напишите запрос для определения количества предметов, изучаемых на каждом курсе.
# 12. Для каждого университета напишите запрос, выводящий суммарную стипендию обучающихся в нем студентов, с последующей сортировкой списка по этому значению.
# 13. Для каждого семестра напишите запрос, выводящий общее количество часов, отводимое на изучение соответствующих предметов.
# 14. Для каждого студента напишите запрос, выводящий среднее значение оценок, полученных им на всех экзаменах.
# 15. Для каждого студента напишите запрос, выводящий среднее значение оценок, полученных им по каждому предмету.
# 16. Напишите запрос, выводящий количество студентов, проживающих в каждом городе. Список отсортировать в порядке убывания количества студентов.
# 17. Для каждого университета напишите запрос, выводящий количество обучающихся в нем студентов, с последующей сортировкой списка по этому количеству.
# 18. Для каждого университета напишите запрос, выводящий количество работающих в нем преподавателей, с последующей сортировкой списка по этому количеству.
# 19. Для каждого университета напишите запрос, выводящий сумму стипендии, выплачиваемой студентам каждого курса.
# 20. Для каждого города напишите запрос, выводящий максимальный рейтинг университетов, в нем расположенных, с последующей сортировкой списка по значениям рейтингов.
# 21. Для каждого дня сдачи экзаменов напишите запрос, выводящий среднее значение всех экзаменационных оценок.
# 22. Для каждого дня сдачи экзаменов напишите запрос, выводящий общее количество студентов, сдававших экзамены.
# 23. Для каждого дня сдачи экзаменов напишите запрос, выводящий общее количество экзаменов, сдававшихся каждым студентом.
# 24. Для каждого преподавателя напишите запрос, выводящий количество преподаваемых им предметов.
# 25. Напишите запрос, выполняющий вывод списка студентов, имеющих только отличные оценки. Результат отстортируйте по идентификатору студента.

# %% [markdown]
# # Решения

# %%
# 1 Напишите запрос для подсчета количества студентов, сдававших экзамен по предмету обучения с идентификатором 73.

s = """
SELECT count(STUDENT_ID) FROM EXAM_MARKS WHERE MARK IS NOT NULL AND SUBJ_ID = 73;
"""
crs.execute(s).fetchall()
# Out:
# [(4,)]

# %%
# 2. Напишите запрос, который позволяет подсчитать в таблице EXAM_MARKS количество различных предметов обучения.

s = """
SELECT count(distinct subj_id) AS Number
    FROM exam_marks
"""
crs.execute(s).fetchall()
# Out:
# [(9,)]

# %%
# 3. Напишите запрос, который для каждого студента выполняет выборку его идентификатора и минимальной из полученных им оценок.

s = '''
SELECT student_id, min(mark) as "Min_mark"
    from 'exam_marks'
    group by student_id;
'''
print(crs.execute(s).fetchall())
# Out:
# [(1, 1), (6, 4), (10, 5), (12, 2), (15, 5), (32, 4), (55, 5), (62, 4), (64, 4), (65, 1), (71, 3), (73, 1), (76, 2), (77, 1), (79, 1), (82, 5), (83, 1), (85, 1), (88, 5), (90, 4), (91, 5), (92, 5), (97, 1), (99, 5), (101, 2), (103, 2), (105, 3), (110, 1), (116, 1), (117, 4), (123, 2), (126, 1), (128, 3), (149, 2), (203, 3)]

# %%
# 4. Напишите запрос, который для каждого студента выполняет выборку его идентификатора и максимальной из полученных им оценок.

s = """
SELECT student_id, MAX(mark)
FROM exam_marks
GROUP BY student_id
"""
print(crs.execute(s).fetchall())
# Out:
# [(1, 1), (6, 4), (10, 5), (12, 5), (15, 5), (32, 4), (55, 5), (62, 4), (64, 4), (65, 1), (71, 3), (73, 1), (76, 2), (77, 1), (79, 1), (82, 5), (83, 1), (85, 4), (88, 5), (90, 4), (91, 5), (92, 5), (97, 1), (99, 5), (101, 2), (103, 2), (105, 3), (110, 1), (116, 1), (117, 4), (123, 2), (126, 1), (128, 5), (149, 2), (203, 3)]

# %%
# 5. Напишите запрос, выполняющий вывод первой по алфавиту фамилии студента, начинающейся на букву "И"

s = '''
select surname
from student
where surname like 'И%' order by surname limit 1;
'''
crs.execute(s).fetchall()
# Out:
# [('Иванов',)]

# %%
# 5 var 2.
s = """
select min(surname) from student
    where surname like 'И%';
"""
crs.execute(s).fetchall()
# Out:
# [('Иванов',)]

# %%
# 6. Напишите запрос, который для каждого предмета обучения выводит наименование предмета 
# и максимальное значение номера семестра, в котором этот предмет преподается.

s = """
SELECT subj_name, max(semester)
    FROM subject
    GROUP by subj_name
"""
crs.execute(s).fetchall()
# Out:
# [('Анализ данных', 1),
#  ('Английский язык', 3),
#  ('Информатика', 1),
#  ('История', 4),
#  ('Математика', 2),
#  ('ОБЖ', 2),
#  ('Обработка данных и моделирование в Excel', 3),
#  ('Программирование на языках Python и SQL', 2),
#  ('Теория вероятностей и математическая статистика', 4),
#  ('Физика', 1),
#  ('Физкультура', 5)]

# %%
#7. Напишите запрос, который для каждого конкретного дня сдачи экзамена 
# выводит данные о количестве студентов, сдававших экзамен в этот день.

s = 'select date(exam_date), count(student_id) from exam_marks group by date(exam_date)'
crs.execute(s).fetchall()
# Out:
# [('2000-01-18', 1),
#  ('2000-01-23', 2),
#  ('2006-05-12', 1),
#  ('2006-06-17', 1),
#  ('2019-05-26', 1),
#  ('2019-05-29', 9),
#  ('2019-09-02', 1),
#  ('2019-12-25', 1),
#  ('2019-12-31', 1),
#  ('2020-02-10', 1),
#  ('2020-02-21', 3),
#  ('2020-02-22', 1),
#  ('2020-05-26', 7),
#  ('2020-05-27', 2),
#  ('2020-08-18', 1),
#  ('2020-09-21', 1),
#  ('2020-10-24', 1),
#  ('2020-12-03', 1),
#  ('2021-06-02', 5)]

# %%
# 8. Напишите запрос, выдающий средний балл для каждого студента.

s = """
SELECT STUDENT_ID, AVG(MARK) AS "Средний балл"
FROM EXAM_MARKS
GROUP BY STUDENT_ID
"""
result=crs.execute(s).fetchall()
print(len(result))
result
# Out:
# 35
# [(1, 1.0),
#  (6, 4.0),
#  (10, 5.0),
#  (12, 3.5),
#  (15, 5.0),
#  (32, 4.0),
#  (55, 5.0),
#  (62, 4.0),
#  (64, 4.0),
#  (65, 1.0),
#  (71, 3.0),
#  (73, 1.0),
#  (76, 2.0),
#  (77, 1.0),
#  (79, 1.0),
#  (82, 5.0),
#  (83, 1.0),
#  (85, 2.5),
#  (88, 5.0),
#  (90, 4.0),
#  (91, 5.0),
#  (92, 5.0),
#  (97, 1.0),
#  (99, 5.0),
#  (101, 2.0),
#  (103, 2.0),
#  (105, 3.0),
#  (110, 1.0),
#  (116, 1.0),
#  (117, 4.0),
#  (123, 2.0),
#  (126, 1.0),
#  (128, 4.0),
#  (149, 2.0),
#  (203, 3.0)]

# %%
#8 var 2

s="""
SELECT EXAM_MARKS.STUDENT_ID, SURNAME || ' ' || SUBSTR(NAME, 1, 1) || '. ' AS "ФИ", AVG(MARK) AS "Средний балл"
    FROM EXAM_MARKS LEFT JOIN STUDENT
    ON (EXAM_MARKS.STUDENT_ID = STUDENT.STUDENT_ID)
    GROUP BY EXAM_MARKS.STUDENT_ID
"""
result=crs.execute(s).fetchall()
print(len(result))
result
# Out:
# 35
# [(1, 'Иванов И. ', 1.0),
#  (6, 'Сидоров В. ', 4.0),
#  (10, 'Кузнецов Б. ', 5.0),
#  (12, 'Зайцева О. ', 3.5),
#  (15, None, 5.0),
#  (32, 'Котов П. ', 4.0),
#  (55, 'Белкин В. ', 5.0),
#  (62, 'Семенова В. ', 4.0),
#  (64, 'Жук О. ', 4.0),
#  (65, 'Сергеева Ф. ', 1.0),
#  (71, 'Кондрат С. ', 3.0),
#  (73, 'Одинцова Л. ', 1.0),
#  (76, 'Мельникова Д. ', 2.0),
#  (77, 'Мишина С. ', 1.0),
#  (79, 'Афанасьева А. ', 1.0),
#  (82, 'Лапина Э. ', 5.0),
#  (83, 'Сорокина И. ', 1.0),
#  (85, 'Казакова М. ', 2.5),
#  (88, 'Жданова И. ', 5.0),
#  (90, 'Костина К. ', 4.0),
#  (91, 'Блохина И. ', 5.0),
#  (92, 'Мельникова С. ', 5.0),
#  (97, 'Вишнякова А. ', 1.0),
#  (99, 'Борисова М. ', 5.0),
#  (101, 'Калашников Е. ', 2.0),
#  (103, 'Трофимов В. ', 2.0),
#  (105, 'Антонов А. ', 3.0),
#  (110, 'Суханов К. ', 1.0),
#  (116, 'Федоров Г. ', 1.0),
#  (117, 'Лазарев К. ', 4.0),
#  (123, 'Веселов Т. ', 2.0),
#  (126, 'Жуков П. ', 1.0),
#  (128, 'Васильев М. ', 4.0),
#  (149, 'Вячеслав П. ', 2.0),
#  (203, 'Петрова Е. ', 3.0)]

# %%
# 9 Напишите запрос, выдающий средний балл для экзамена по каждому предмету.

s = """
SELECT subj_id, AVG(mark)
FROM exam_marks
GROUP BY subj_id;
"""
result=crs.execute(s).fetchall()
print(len(result))
result
# Out:
# 9
# [(10, 3.6666666666666665),
#  (11, 1.0),
#  (12, 2.0),
#  (13, 2.5),
#  (22, 2.8333333333333335),
#  (43, 2.0),
#  (56, 3.1666666666666665),
#  (73, 3.0),
#  (94, 3.6666666666666665)]

# %%
# 10. Напишите запрос, определяющий количество сдавших студентов для каждого предмета (оценка больше двух).

s = """
SELECT subj_id, count(distinct(student_id)) as "Amount_of_students"
    FROM exam_marks
    where mark > 2
    group by subj_id;
"""
result=crs.execute(s).fetchall()
print(len(result))
result
# Out:
# 8
# [(10, 7), (12, 1), (13, 1), (22, 3), (43, 1), (56, 3), (73, 3), (94, 2)]

# %%
# 11. Напишите запрос для определения количества предметов, изучаемых на каждом курсе.

s = """
select round(semester/2.0), count(subj_id)
    from subject
    group by round(semester/2.0);
"""
result=crs.execute(s).fetchall()
print(len(result))
result
# Out:
# 3
# [(1.0, 6), (2.0, 5), (3.0, 1)]

# %%
#12. Для каждого университета напишите запрос, выводящий суммарную стипендию обучающихся в нем студентов, 
# с последующей сортировкой списка по этому значению.

s = """
select univ_id, sum(stipend) as Sum_of_stipend
    from student
    group by univ_id
    order by Sum_of_stipend asc;
"""
result=crs.execute(s).fetchall()
print(len(result))
result
# Out:
# 12
# [(15, 350),
#  (11, 400),
#  (45, 650),
#  (48, 800),
#  (18, 850),
#  (32, 1050),
#  (47, 1050),
#  (46, 1250),
#  (14, 1350),
#  (22, 1480),
#  (44, 1730),
#  (10, 2250)]

# %% [markdown]
# ДЗ на 14.03
#
# Выполнить оставшиеся задания 13-25
#
# Оценка макс. 1 балл.
